# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_vida= pd.read_csv('vidaP.csv')
type(df_vida)
# Out:
# pandas.core.frame.DataFrame

# %%
df_vida["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df_vida.describe().T
# Out:
#             count          mean           std           min           25%  \
# year       1704.0  1.979500e+03  1.726533e+01   1952.000000  1.965750e+03
# pop        1704.0  2.960121e+07  1.061579e+08  60011.000000  2.793664e+06
# lifeExp    1704.0  5.947444e+01  1.291711e+01     23.599000  4.819800e+01
# gdpPercap  1704.0  7.215327e+03  9.857455e+03    241.165876  1.202060e+03
#
#                     50%           75%           max
# year       1.979500e+03  1.993250e+03  2.007000e+03
# pop        7.023596e+06  1.958522e+07  1.318683e+09
# lifeExp    6.071250e+01  7.084550e+01  8.260300e+01
# gdpPercap  3.531847e+03  9.325462e+03  1.135231e+05

# %%
df_vida.head(15)
# Out:
#         country  year         pop continent  lifeExp    gdpPercap
# 0   Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 1   Afghanistan  1957   9240934.0      Asia   30.332   820.853030
# 2   Afghanistan  1962  10267083.0      Asia   31.997   853.100710
# 3   Afghanistan  1967  11537966.0      Asia   34.020   836.197138
# 4   Afghanistan  1972  13079460.0      Asia   36.088   739.981106
# 5   Afghanistan  1977  14880372.0      Asia   38.438   786.113360
# 6   Afghanistan  1982  12881816.0      Asia   39.854   978.011439
# 7   Afghanistan  1987  13867957.0      Asia   40.822   852.395945
# 8   Afghanistan  1992  16317921.0      Asia   41.674   649.341395
# 9   Afghanistan  1997  22227415.0      Asia   41.763   635.341351
# 10  Afghanistan  2002  25268405.0      Asia   42.129   726.734055
# 11  Afghanistan  2007  31889923.0      Asia   43.828   974.580338
# 12      Albania  1952   1282697.0    Europe   55.230  1601.056136
# ...

# %%
df_vida2=df_vida.copy()

# %%
df_vida2.dropna(how='any')
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
vida_plot=df_vida2.dropna(how='any')
vida_plot=vida_plot.set_index("country")
vida_plot=vida_plot.drop(["continent"],axis=1).T
vida_plot
# Out:
# country     Afghanistan   Afghanistan   Afghanistan   Afghanistan  \
# year       1.952000e+03  1.957000e+03  1.962000e+03  1.967000e+03
# pop        8.425333e+06  9.240934e+06  1.026708e+07  1.153797e+07
# lifeExp    2.880100e+01  3.033200e+01  3.199700e+01  3.402000e+01
# gdpPercap  7.794453e+02  8.208530e+02  8.531007e+02  8.361971e+02
#
# country     Afghanistan   Afghanistan   Afghanistan   Afghanistan  \
# year       1.972000e+03  1.977000e+03  1.982000e+03  1.987000e+03
# pop        1.307946e+07  1.488037e+07  1.288182e+07  1.386796e+07
# lifeExp    3.608800e+01  3.843800e+01  3.985400e+01  4.082200e+01
# gdpPercap  7.399811e+02  7.861134e+02  9.780114e+02  8.523959e+02
#
# country     Afghanistan   Afghanistan  ...      Zimbabwe      Zimbabwe  \
# year       1.992000e+03  1.997000e+03  ...  1.962000e+03  1.967000e+03
# pop        1.631792e+07  2.222742e+07  ...  4.277736e+06  4.995432e+06
# lifeExp    4.167400e+01  4.176300e+01  ...  5.235800e+01  5.399500e+01
# ...

# %%
vida_plot.iloc[2,1:18].plot(kind='box')
# Out:
# <AxesSubplot:>
